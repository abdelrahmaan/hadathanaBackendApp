# %%
import pandas as pd

# %%
data = pd.read_csv('out_people_csv/tarajm_people.csv')
data.head()
# Out:
#       id                              url  http_status        scraped_at_utc  \
# 0  10083  https://tarajm.com/people/10083          200  2026-02-10T18:23:06Z
# 1  10084  https://tarajm.com/people/10084          200  2026-02-10T18:23:09Z
# 2  10087  https://tarajm.com/people/10087          200  2026-02-10T18:23:11Z
# 3  10109  https://tarajm.com/people/10109          200  2026-02-10T18:23:13Z
# 4  10226  https://tarajm.com/people/10226          200  2026-02-10T18:23:14Z
#
#               name                                            summary  \
# 0  عبد القادر عيسى  هُوَ سَيِّدِي الشَّيْخُ عَبْدُ القَادِرِ بْنُ ...
# 1     محمد الهاشمي  الشَيْخِ الْمُرَبِّي الكَبِيرِ وَالعَارِفِ بِا...
# 2      أحمد العلوي                                      ( ابن عليوة )
# 3   الفضيل بن عياض                                    ( القاضي عياض )
# 4     أحمد الرفاعي                                    ( ابو النورين )
#
#                                          translation  \
# ...

# %%
data.shape
# Out:
# (26771, 10)

# %%
from pprint import pprint
print(data['name'][0:].values)
pprint(data['summary'][0:].values)
# Out:
# ['عبد القادر عيسى' 'محمد الهاشمي' 'أحمد العلوي' ... 'جمال الدين الكشميري'
#  'أحمد بن نظام الدين بن فيض الله المانكبوري' 'كمال الدين بن موسى الكشميري']
# array(['هُوَ سَيِّدِي الشَّيْخُ عَبْدُ القَادِرِ بْنُ عَبْدِ اللِه بْنِ قَاسِمِ بْنِ مُحَمَّدٍ بْنِ عِيسَى عَزِيزِي الحَلَبِيِّ الشَّاذِلِيِّ، يَصِلُ نَسَبُهُ بِالشَّيْخِ عُمَرَ البَعَّاجِ إِلَى سِبْطِ رَسُولِ اللهِ صَلَّى اللهُ عَلَيْهِ وَعَلَى آلِهِ وَصَحْبِهِ وَسَلَّمَ، الحُسَيْنِ بْنِ عَلِيٍّ رَضِيَ اللهُ عَنْهُمَا. وُلِدَ في مَدِينَةِ حَلَبَ الشَّهَبَاء سَنَةَ ١٣٣٨ مِنَ الهِجْرَةِ النَّبَوِيَّةِ الشَّرِيفَةِ، وَالْمُصَادِفِ ١٩٢٠ مِنْ مِيلَادِ السَّيِّدِ الْمَسِيحِ عَلَيْهِ السَّلَامُ.',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26771 entries, 0 to 26770
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  26771 non-null  int64
#  1   url                 26771 non-null  object
#  2   http_status         26771 non-null  int64
#  3   scraped_at_utc      26771 non-null  object
#  4   name                26768 non-null  object
#  5   summary             26624 non-null  object
#  6   translation         26526 non-null  object
#  7   fields_json         26771 non-null  object
#  8   page_sections_json  26771 non-null  object
#  9   all_hrefs           26768 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 2.0+ MB

# %%
data.to_parquet('out_people_csv/tarajm_people.parquet', index=False)
